# %% [markdown]
# this is text
# i love his to much

# %% [markdown]
# tngneogneobneienbeon

# %%
3+ 3
# Out:
# 6

# %%
4+6
# Out:
# 10

# %%
print(4+5)
# Out:
# 9

# %%
2+3
print(4*4)
# Out:
# 16

# %%
print (2+2)
2+4
# Out:
# 4
# 6

# %% [markdown]
# **bold**
# [this is a link]{www.voda.com}

# %%
# !ls
# Out:
# sample_data

# %%
# %timeit

# %%
salary= 100000

# %%
salary
# Out:
# 100000

# %%
base_salary=100000
bonus_rate=.10

# %%
total_salary= (base_salary) * (1 + bonus_rate)

# %%
total_salary
# Out:
# 110000.00000000001

# %%
lukes_salary= 100000

# %%
comapany_name = 'datawitz'

# %%
comapany_name
# Out:
# 'datawitz'

# %%
job='wfh'

# %%
print(job)
print(comapany_name)
print(lukes_salary)
print(total_salary)
print(base_salary)
print(bonus_rate)
print('good')
# Out:
# wfh
# datawitz
# 100000
# 110000.00000000001
# 100000
# 0.1
# good

# %%
10000
# Out:
# 10000

# %%
salary
# Out:
# 100000

# %%
type(10000)
# Out:
# int

# %%
type(salary)
# Out:
# int

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
"food is good"
# Out:
# 'food is good'

# %%
'food is good'
# Out:
# 'food is good'

# %%
type('food is good')
# Out:
# str

# %%
id(salary)
# Out:
# 136777991893904

# %%
print("whatup ibra")
# Out:
# whatup ibra

# %%
my_print_func = print

# %%
my_print_func("whatup ibra")
# Out:
# whatup ibra

# %%
 print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
print('whata up ibra')
# Out:
# whata up ibra

# %%
def greet():
  return "whata up ibra"

# %%
greet()
# Out:
# 'whata up ibra'

# %%
100000
# Out:
# 100000

# %%
type(100000)
# Out:
# int

# %%
total_salary = 110000
type(total_salary)
# Out:
# int

# %%
bonus_salary= 10000
type(bonus_salary)
# Out:
# int

# %%
base_salary = total_salary - bonus_salary

# %%
base_salary
# Out:
# 100000

# %%
job_title = 'data scientist'

# %%
job_title
# Out:
# 'data scientist'

# %%
remove_word='data'

# %%
type(job_title)
# Out:
# str

# %%
 final_title = job_title - remove_word
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1427509968.py in <cell line: 0>()
# ----> 1 final_title = job_title - remove_word
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
help(str)

# %%
'data ' + 'nerd'

# %%
'data nerd'.capitalize()

# %%
job_id = 345

# %%
type(job_id)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2005703002.py in <cell line: 0>()
# ----> 1 type(job_id)
#
# NameError: name 'job_id' is not defined

# %%
job_id = float(345)

# %%
type(job_id)

# %%
help(float)

# %%
skill='python'

# %%
type(skill)

# %%
skill.upper()

# %%
skill.lower()

# %%
skill.lower()

# %%
'|python'.upper()

# %%
str.lower("python")

# %%
skill=python

# %%
skill='python'

# %%
skill.upper()
# Out:
# 'PYTHON'

# %%
skill.replace('pyt', 'SSENKUNGU')
# Out:
# 'SSENKUNGUhon'

# %%
job_title
# Out:
# 'data scientist'

# %%
job_title.replace('t', 'v', 4)
# Out:
# 'dava scienvisv'

# %%
job_title.split(sep=' ', maxsplit=1)
# Out:
# ['data', 'scientist']

# %%
str.__add__('data',' analyst')
# Out:
# 'data analyst'

# %%
'data analyst'* 6
# Out:
# 'data analystdata analystdata analystdata analystdata analystdata analyst'

# %%
len('data analyst')
# Out:
# 12

# %%
role='data analyst'
skill=python
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2384177317.py in <cell line: 0>()
#       1 role='data analyst'
# ----> 2 skill=python
#
# NameError: name 'python' is not defined

# %%
role + skill

# %%
'role:'+ role

# %%
 help(str)

# %%
"role: {}.format(role)"

# %%
"role{}; skill required:{}".format(role, skill)

# %%
f"role:{role}; skill required:{skill}"

# %%
'role:%s'%(role)

# %%
years_experience='012949855585'

# %%
','.join(years_experience)

# %%
skills=['wert', 'fggh', 'fghj']

# %%
'.'.join(skills)

# %%
help(str)

# %%
5/6

# %%
59 - 54

# %%
5//4

# %%
9%6

# %%
min_salary=20000
max_salary=80000

avg_salary= (min_salary + max_salary)/2

# %%
avg_salary

# %%
applicant_1= 'kelly'
applicant_2= 'najjemba'

# %%
temp_var = applicant_1

# %%
applicant_1=applicant_2

# %%
applicant_2 = temp_var

# %%
applicant_1 , applicant_2

# %%
x=1

# %%
x= x+1

# %%
x

# %%
x +=1

# %%
x

# %%
x*=2

# %%
x

# %%
kelly_salary=60_000
ibra_salary=100_000

# %%
kelly_salary==ibra_salary

# %%
1==1

# %%
2==6

# %%
if 'true':
  print("whats up ibrahim")

# %%
  job_skill='SQL'
  applicant_skill='SQLite'
  if job_skill==applicant_skill:
    print('match')
  else:
    print('not match try elsewhere')
#

# %%
 if job_skill==applicant_skill:
    print('match')
    elif years_experience:
      print('good')
    else:
       print('not match try elsewhere')
#

# %%
if job_skill==applicant_skill:
    print('match')

# %%
job_skills=['kelly','ibrahim''sql','mike']

# %%
help(list)

# %%
job_skills.append('python')

# %%
job_skills

# %%
job_skills.remove('mike')

# %%
job_skills

# %%
len(job_skills)

# %%
job_skills[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2956999284.py in <cell line: 0>()
# ----> 1 job_skills[0]
#
# NameError: name 'job_skills' is not defined

# %%
job_skills.insert(2, 'tableau')

# %%
job_skills

# %%
job_skills.pop(2)

# %%
job_skills

# %%
job_skills.pop(0)

# %%
job_skills

# %%
job_skills[0:0]

# %%
voda = ['python', 'sql', 'excel']
me=['tuple','good','sweet']
all_skills = voda + me

# %%
all_skills

# %%
all_skills[:: 2]

# %%
all_skills[0:]

# %%
all_skills[-2:]

# %%
skill1, skill2, = job_skills

# %%
print(skill1)
print(skill2)

# %%
job_skills

# %%
all_skills[::1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-85618384.py in <cell line: 0>()
# ----> 1 all_skills[::1]
#
# NameError: name 'all_skills' is not defined

# %%
skill_concerned, *skill_not_concerned= job_skills
print(skill_concerned)
print(skill_not_concerned)

# %%
skill_concerned

# %%
dictionaries= {'databases': 'postgresql',
 'langauge':'python',
 'library':'pandas'}

# %%
dictionaries

# %%
help(dict)

# %%
dictionaries['langauge']

# %%
dictionaries.keys()

# %%
dictionaries.pop('databases')

# %%
dictionaries.update({'cloud':'google cloud'})

# %%
dictionaries
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1728562226.py in <cell line: 0>()
# ----> 1 dictionaries
#
# NameError: name 'dictionaries' is not defined

# %%
job_skills = {'tableau','python','sql','tiyiy'}

# %%
job_skills

# %%
help(set)

# %%
job_skills.add('looker')

# %%
job_skills

# %%
job_skills.remove('looker')

# %%
job_skills

# %%
 set(job_skills)

# %%
list(job_skills)

# %%
#tuples are for fixed stuff only unique set of a

# %%
'tuples'
# Out:
# 'tuples'

# %%
voda_skills=('python', 'sql', 'excel')

# %%
voda_skills
# Out:
# ('python', 'sql', 'excel')

# %%
voda_skills[0:2]
# Out:
# ('python', 'sql')

# %%
new_skills=('tableau', 'looker')

# %%
voda_skills + new_skills
# Out:
# ('python', 'sql', 'excel', 'tableau', 'looker')

# %%
vosa_skills += new_skills
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1634234835.py in <cell line: 0>()
# ----> 1 vosa_skills += new_skills
#
# NameError: name 'vosa_skills' is not defined

# %%
def calculate_salary():
  bonus_salary = 100000
bonus_rate = 0.1
total_salary = bonus_salary * ( 1 + bonus_rate):
return total_salary

# %%
def calculated_salary(bonus_salary_1, bonus_rate_1=.7):

  total_salary = bonus_salary_1 * ( 1 + bonus_rate_1)
  return total_salary

# %%
salary_1=100000
rate=.5

calculated_salary(999, .94)

# %%
  calculated_salary(29, .94)

# %%
calculated_salary(20009, .94)

# %%
trial = lambda x: x*2
trial(80)

# %%
trial(67)

# %%
trial(45)

# %%
(lambda x,y: x*2+y)(3000,8)
# Out:
# 6008

# %%
calculated_salary(234, 4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-673934457.py in <cell line: 0>()
# ----> 1 calculated_salary(234, 4)
#
# NameError: name 'calculated_salary' is not defined

# %%
def calculated_salary(bonus_salary_1, bonus_rate_1=.7):

  total_salary = bonus_salary_1 * ( 1 + bonus_rate_1)
  return total_salary

# %%
bonus_rate_1=.7
calculated_salary(234, 4)

# %%
bonus_rate_1=.0
calculated_salary(234, .9)

# %%
salary_list

# %%
total_salary

# %%
salary_list=[76543,2345,654,1234,6543,2345,345,98,456,876]

total_salary_list = [(lambda c:c*1.2)(salary) for salary in salary_list]

total_salary_list

# %%
data_jobs = {
    1: {"job_title": "Data Analyst", "job_skills": ["Python", "SQL", "Excel", "Data Visualization"], "remote": True},
    2: {"job_title": "Junior Data Scientist", "job_skills": ["Python", "Statistics", "Pandas", "Machine Learning"], "remote": False},
    3: {"job_title": "Machine Learning Engineer", "job_skills": ["Python", "TensorFlow", "Deep Learning", "Model Deployment"], "remote": True},
    4: {"job_title": "Business Intelligence Analyst", "job_skills": ["SQL", "Power BI", "Tableau", "Reporting"], "remote": False},
    5: {"job_title": "Data Engineer", "job_skills": ["Python", "SQL", "ETL", "Apache Spark"], "remote": True},
    6: {"job_title": "AI Research Scientist", "job_skills": ["Python", "PyTorch", "Neural Networks", "Research Methods"], "remote": True},
    7: {"job_title": "Statistician", "job_skills": ["R", "Statistics", "Data Modeling", "Hypothesis Testing"], "remote": False},
    16: {"job_title": "Product Data Scientist", "job_skills": ["Python", "A/B Testing", "SQL", "Experiment Design"], "remote": True},
    17: {"job_title": "Sports Data Analyst", "job_skills": ["Python", "Statistics", "Data Visualization", "Sports Analytics"], "remote": False},
    18: {"job_title": "Climate Data Scientist", "job_skills": ["Python", "Geospatial Analysis", "Statistics", "Machine Learning"], "remote": True},
    19: {"job_title": "Fraud Detection Analyst", "job_skills": ["Python", "Anomaly Detection", "Machine Learning", "SQL"], "remote": True},
    20: {"job_title": "Big Data Analyst", "job_skills": ["Hadoop", "Spark", "Python", "SQL"], "remote": False}
}

list (filter(lambda job: job['remote'] and "Python" in job['job_skills'], data_jobs.values()))

# %%
help(filter)

# %%
filter(lambda jobs:job['remote'], data_jobs)

# %%
1: {"job_title": "Data Analyst", "job_skills": ["Python", "SQL", "Excel", "Data Visualization"], "remote": True},
2: {"job_title": "Junior Data Scientist", "job_skills": ["Python", "Statistics", "Pandas", "Machine Learning"], "remote": False},
3: {"job_title": "Machine Learning Engineer", "job_skills": ["Python", "TensorFlow", "Deep Learning", "Model Deployment"], "remote": True},
4: {"job_title": "Business Intelligence Analyst", "job_skills": ["SQL", "Power BI", "Tableau", "Reporting"], "remote": False},
5: {"job_title": "Data Engineer", "job_skills": ["Python", "SQL", "ETL", "Apache Spark"], "remote": True},
6: {"job_title": "AI Research Scientist", "job_skills": ["Python", "PyTorch", "Neural Networks", "Research Methods"], "remote": True},
7: {"job_title": "Statistician", "job_skills": ["R", "Statistics", "Data Modeling", "Hypothesis Testing"], "remote": False},
8: {"job_title": "Quantitative Analyst", "job_skills": ["Python", "Financial Modeling", "Machine Learning", "Statistics"], "remote": False},
9: {"job_title": "Data Science Consultant", "job_skills": ["Python", "SQL", "Business Analytics", "Communication"], "remote": True},
10: {"job_title": "Healthcare Data Scientist", "job_skills": ["Python", "Biostatistics", "Machine Learning", "Healthcare Data"], "remote": False}

# %%
import my_module
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3758733343.py in <cell line: 0>()
# ----> 1 import my_module
#
# ModuleNotFoundError: No module named 'my_module'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
my_module.skill_list

# %%
my_module.skill('python')

# %%
salary_list=[10000, 20000, 300000, 400000, 500000]

# %%
from statistics import mean, mode, median

# %%
mean(salary_list)

# %%
mode(salary_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-370298712.py in <cell line: 0>()
# ----> 1 mode(salary_list)
#
# NameError: name 'mode' is not defined

# %%
median(salary_list)

# %%
from datetime import datetime

# %%
datetime.now

# %%
datetime.now()

# %%
test_Date = datetime.now()

# %%
print(test_Date)

# %%
import pandas as pd
contents = pd.read_csv('sample_data/california_housing_test.csv')

# %%
contents
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
type(contents['total_bedrooms'].sum())
# Out:
# numpy.float64

# %%
# !pip install pandas

# %%
! pip list
# Out:
# Package                                  Version
# ---------------------------------------- -------------------
# absl-py                                  1.4.0
# accelerate                               1.12.0
# access                                   1.1.10.post3
# affine                                   2.4.0
# aiofiles                                 24.1.0
# aiohappyeyeballs                         2.6.1
# aiohttp                                  3.13.3
# aiosignal                                1.4.0
# aiosqlite                                0.22.1
# alabaster                                1.0.0
# albucore                                 0.0.24
# albumentations                           2.0.8
# ale-py                                   0.11.2
# alembic                                  1.18.1
# altair                                   5.5.0
# annotated-doc                            0.0.4
# annotated-types                          0.7.0
# ...

# %%
 # !pip install pyjokes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 kB 2.2 MB/s eta 0:00:00
# ...

# %%
import pyjokes

# %%
pyjokes.get_jokes()
# Out:
# ["Complaining about the lack of smoking shelters, the nicotine addicted Python programmers said there ought to be 'spaces for tabs'.",
#  'Ubuntu users are apt to get this joke.',
#  'Obfuscated Reality Mappers (ORMs) can be useful database tools.',
#  'Asked to explain Unicode during an interview, Geoff went into detail about his final year university project. He was not hired.',
#  "Triumphantly, Beth removed Python 2.7 from her server in 2030. 'Finally!' she said with glee, only to see the announcement for Python 4.4.",
#  "An SQL query goes into a bar, walks up to two tables and asks, 'Can I join you?'",
#  'When your hammer is C++, everything begins to look like a thumb.',
#  'If you put a million monkeys at a million keyboards, one of them will eventually write a Java program. The rest of them will write Perl.',
#  'To understand recursion you must first understand recursion.',
# ...

# %%
class BaseSalary:
  def __init__(self, base_salary, bonus_rate=0.1, symbol="$"):
    self.base_salary = base_salary
    self.bonus_rate = bonus_rate
    self.symbol = symbol
    self.total_salary = base_salary*( 1 + bonus_rate)
    self.bonus = (self.total_salary- base_salary) / base_salary

  def __repr__(self):
    return f'{self.symbol}{self.base_salary:,.0f}'
  def calculate_salary(self):
    return f'{self.symbol}{self.total_salary:,.0f}'
  def calculate_bonus(self):
    return f'{self.symbol}{self.bonus:,.0f}'

# %%
salary= BaseSalary(20000)

# %%
salary
# Out:
# $20,000

# %%
salary
# Out:
# $20,000

# %%
salary.calculate_salary()
# Out:
# '$22,000'

# %%
salary
# Out:
# $20,000

# %%
salary.calculate_salary()
# Out:
# '$22,000'

# %%
salary.calculate_bonus()
# Out:
# '$0'

# %%
class BaseSalary:
  def __init__(self, base_salary, bonus_rate=0.1, symbol="$"):
    self.base_salary = base_salary
    self.bonus_rate = bonus_rate
    self.symbol = symbol
    self.total_salary = base_salary*( 1 + bonus_rate)
    self.bonus = (self.total_salary- self.base_salary)

  def __repr__(self):
    return f'{self.symbol}{self.base_salary:,.0f}'
  def show_salary(self):
    return f'{self.symbol}{self.total_salary:,.0f}'
  def show_bonus(self):
    return f'{self.symbol}{self.bonus:,.0f}'

# %%
salary.show_bonus()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3463629628.py in <cell line: 0>()
# ----> 1 salary.show_bonus()
#
# AttributeError: 'BaseSalary' object has no attribute 'show_bonus'

# %%
salary

# %%
salary.show_salary()

# %%
df

# %%
1PIP LIST

# %%
# !pip list
# Out:
# Package                                  Version
# ---------------------------------------- -------------------
# absl-py                                  1.4.0
# accelerate                               1.12.0
# access                                   1.1.10.post3
# affine                                   2.4.0
# aiofiles                                 24.1.0
# aiohappyeyeballs                         2.6.1
# aiohttp                                  3.13.3
# aiosignal                                1.4.0
# aiosqlite                                0.22.1
# alabaster                                1.0.0
# albucore                                 0.0.24
# albumentations                           2.0.8
# ale-py                                   0.11.2
# alembic                                  1.18.1
# altair                                   5.5.0
# annotated-doc                            0.0.4
# annotated-types                          0.7.0
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.arange(2, 100, 0.5)
y = np.cos(x)
plt.plot(x,y)

# %%
# !pip install datasets

# %%
from datasets import load_dataset

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_posted_date']
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]
# 0        2023-06-16 13:44:15
# 1        2023-01-14 13:18:07
# 2        2023-10-10 13:14:55
# 3        2023-07-04 13:01:41
# 4        2023-08-07 14:29:36
#                  ...
# 785736   2023-03-13 06:16:16
# 785737   2023-03-12 06:18:18
# 785738   2023-03-12 06:32:36
# 785739   2023-03-12 06:32:15
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = ['1, 2, 3, 4']
y = ['1, 2, 3, 4']

plt.plot(x, y)
plt.show()

# %%
df.job_posted_date.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-201690589.py in <cell line: 0>()
# ----> 1 df.job_posted_date.head()
#
# NameError: name 'df' is not defined

# %%
plt.plot(df.job_posted_date, df.job_posted_date)
plt.show()

# %%
date_counts = df.job_posted_date.value_counts()

# %%
date_counts

# %%
plt.plot(date_counts.index, date_counts)
date_counts =date_counts.sort_index()
plt.show()

# %%
df['job_posted_month'] = df['job_posted_date'].dt.month
df

# %%
monthly_counts = df.job_posted_month.value_counts()

# %%
monthly_counts = monthly_counts.sort_index()
monthly_counts

# %%
plt.plot(monthly_counts.index, monthly_counts.values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1706838573.py in <cell line: 0>()
# ----> 1 plt.plot(monthly_counts.index, monthly_counts.values)
#
# NameError: name 'plt' is not defined

# %%
series = pd.Series([10, 20, 45, 78], index=['a', 'b', 'c', 'd'])

# %%
series.values
# Out:
# array([10, 20, 45, 78])

# %%
job_counts = df.job_title_short.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1500953862.py in <cell line: 0>()
# ----> 1 job_counts = df.job_title_short.value_counts()
#
# NameError: name 'df' is not defined

# %%
job_counts = job_counts.sort_values(ascending=True)
plt.barh(job_counts.index, job_counts)
plt.title('Number of Data Jobs by Title')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3987691499.py in <cell line: 0>()
# ----> 1 job_counts = job_counts.sort_values(ascending=True)
#       2 plt.barh(job_counts.index, job_counts)
#       3 plt.title('Number of Data Jobs by Title')
#       4 plt.legend()
#       5 plt.show()
#
# NameError: name 'job_counts' is not defined

# %%
df['salary_year_avg']

# %%
df.salary_year_avg.notna()

# %%
df
