# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from datasets import load_dataset
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# %%
from datasets import load_dataset

# %%
dataset = load_dataset('lukebarousse/data_jobs')

# %%
df = dataset['train'].to_pandas()

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.iloc[0:10]
# Out:
#                 job_title_short  \
# job index
# 0          Senior Data Engineer
# 1                  Data Analyst
# 2                 Data Engineer
# 3                 Data Engineer
# 4                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 7                 Data Engineer
# 8              Business Analyst
# 9                Data Scientist
#
#                                                    job_title  \
# job index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1                                               Data Analyst
# 2          Data Engineer/Scientist/Analyst, Mid or Senior...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                     Data Engineer- Sr Jobs
# 5                                          GCP Data Engineer
# 6                          Senior Data Engineer  - GCP Cloud
# 7                                              Data Engineer
# ...

# %%
df.loc[:,'salary_rate':'salary_hour_avg'].dropna(subset="salary_rate")
# Out:
#           salary_rate  salary_year_avg  salary_hour_avg
# job index
# 28               year         109500.0        55.288462
# 43               hour         115000.0        97.500000
# 51               hour         115000.0        72.500000
# 77               year         140000.0        55.288462
# 92               year         120000.0        55.288462
# ...               ...              ...              ...
# 785624           year         139216.0        55.288462
# 785641           year         150000.0        55.288462
# 785648           year         221875.0        55.288462
# 785682           year         157500.0        55.288462
# 785692           year         157500.0        55.288462
#
# [33067 rows x 3 columns]

# %%
median_salary_year = df['salary_year_avg'].median()

# %%
salary_hour_avg = df['salary_hour_avg'].median()

# %%
salary_hour_avg = df['salary_hour_avg'].fillna(median_salary_year / 2080)

# %%
df_filled = df

df_filled['salary_year_avg'] = df_filled['salary_year_avg'].fillna(median_salary_year,)
df_filled['salary_hour_avg'] = df_filled['salary_hour_avg'].fillna(salary_hour_avg)

# %%
df_filled.loc[:10, 'salary_year_avg':'salary_hour_avg']
# Out:
#     salary_year_avg  salary_hour_avg
# 0          115000.0        55.288462
# 1          115000.0        55.288462
# 2          115000.0        55.288462
# 3          115000.0        55.288462
# 4          115000.0        55.288462
# 5          115000.0        55.288462
# 6          115000.0        55.288462
# 7          115000.0        55.288462
# 8          115000.0        55.288462
# 9          115000.0        55.288462
# 10         115000.0        55.288462

# %%
df_unique = df_filled
df_unique= df_unique.drop_duplicates()
print('length of original df: ', len(df_filled))
print('length of dropped duplicates df: ', len(df_unique))
print('rows dropped:', len(df_filled) - len(df_unique))
# Out:
# length of original df:  785741
# length of dropped duplicates df:  785640
# rows dropped: 101

# %%
df_unique= df_unique.drop_duplicates(subset=['job_title','company_name',])
print('length of original df: ', len(df_filled))
print('length of dropped duplicates df: ', len(df_unique))
print('rows dropped:', len(df_filled) - len(df_unique))
# Out:
# length of original df:  785741
# length of dropped duplicates df:  508042
# rows dropped: 277699

# %%
df.sample(3, random_state=42)
# Out:
#               job_title_short                  job_title  \
# 502901   Senior Data Engineer       Senior Data Engineer
# 406337  Senior Data Scientist  Senior Analytics Engineer
# 659951          Data Engineer              Data Engineer
#
#                    job_location       job_via job_schedule_type  \
# 502901              St Paul, MN     via BeBee         Full-time
# 406337               London, UK  via LinkedIn         Full-time
# 659951  Newcastle upon Tyne, UK    via Indeed         Full-time
#
#         job_work_from_home         search_location     job_posted_date  \
# 502901               False  Florida, United States 2023-12-17 11:09:06
# 406337               False          United Kingdom 2023-10-06 16:09:56
# 659951               False          United Kingdom 2023-09-06 10:11:25
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 502901                  False                 False   United States
# ...

# %%
df_original = dataset['train'].to_pandas()

# %%
df_original
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df.pivot_table(index='job_country',values='salary_year_avg', columns='job_title_short', aggfunc='median')
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_country
# Afghanistan              115000.0             NaN      115000.0
# Albania                  115000.0        115000.0      115000.0
# Algeria                  115000.0        115000.0      115000.0
# Angola                   115000.0             NaN      115000.0
# Argentina                115000.0        115000.0      115000.0
# ...                           ...             ...           ...
# Venezuela                115000.0        115000.0      115000.0
# Vietnam                  115000.0        115000.0      115000.0
# Yemen                    115000.0             NaN      115000.0
# Zambia                   115000.0        115000.0      115000.0
# Zimbabwe                 115000.0        115000.0      115000.0
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# Afghanistan                NaN        115000.0                        NaN
# ...

# %%
 df.groupby('job_title_short')['salary_year_avg'].median()
# Out:
# job_title_short
# Business Analyst             115000.0
# Cloud Engineer               115000.0
# Data Analyst                 115000.0
# Data Engineer                115000.0
# Data Scientist               115000.0
# Machine Learning Engineer    115000.0
# Senior Data Analyst          115000.0
# Senior Data Engineer         115000.0
# Senior Data Scientist        115000.0
# Software Engineer            115000.0
# Name: salary_year_avg, dtype: float64

# %%
top_countries = df['job_country'].value_counts().head(6).index

df_job_country_salary = df.pivot_table(
    values='salary_year_avg',
    index='job_country',
    columns='job_title_short',
    aggfunc='mean'
)

df_job_country_salary = df_job_country_salary.loc[top_countries]
job_titles = ['Data Analyst', 'Data Engineer', 'Data Scientist']
df_job_country_salary = df_job_country_salary[job_titles]
df_job_country_salary
df_job_country_salary.plot(kind='bar')
plt.ylabel('Average Salary Yearly(USD)')
plt.title('Average Salary by Job Title and Country')
plt.xticks(rotation=45)
plt.legend(title='Job Title', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel('')
plt.show()

# %%
top_countries = df['job_country'].value_counts().head(6).index
df_job_country_salary = df.pivot_table(
    values='salary_year_avg',
    index='job_country',
    columns='job_title_short',
    aggfunc='median'
)

df_job_country_salary = df_job_country_salary.loc[top_countries]
job_titles = ['Data Analyst', 'Data Engineer', 'Data Scientist']
df_job_country_salary = df_job_country_salary[job_titles]
df_job_country_salary.plot(kind='bar')
# Out:
# <Axes: xlabel='job_country'>

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.index.name ='job index'
df.head(3)
# Out:
#                 job_title_short  \
# job index
# 0          Senior Data Engineer
# 1                  Data Analyst
# 2                 Data Engineer
#
#                                                    job_title  \
# job index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1                                               Data Analyst
# 2          Data Engineer/Scientist/Analyst, Mid or Senior...
#
#                            job_location           job_via job_schedule_type  \
# job index
# 0                         Watertown, CT   via Work Nearby         Full-time
# 1          Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
# 2                       Berlin, Germany      via LinkedIn         Full-time
#
#            job_work_from_home       search_location     job_posted_date  \
# job index
# 0                       False  Texas, United States 2023-06-16 13:44:15
# 1                       False                Mexico 2023-01-14 13:18:07
# ...

# %%
 df.index.dtype
# Out:
# dtype('int64')

# %%
df_usa = df[df['job_country'] == 'United States']
df_usa.reset_index(inplace=True)
df_usa
# Out:
#          index       job_title_short  \
# 0            0  Senior Data Engineer
# 1            3         Data Engineer
# 2            5         Data Engineer
# 3            6  Senior Data Engineer
# 4            9        Data Scientist
# ...        ...                   ...
# 206287  785673        Data Scientist
# 206288  785685          Data Analyst
# 206289  785692        Data Scientist
# 206290  785703          Data Analyst
# 206291  785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 1       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 2                                       GCP Data Engineer          Anywhere
# 3                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 4                                       Data Scientist II          Anywhere
# ...

# %%
df_usa.set_index('job index', inplace=True)
df_usa
# Out:
#                 job_title_short  \
# job index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
# ...                         ...
# 785673           Data Scientist
# 785685             Data Analyst
# 785692           Data Scientist
# 785703             Data Analyst
# 785705             Data Analyst
#
#                                                    job_title  \
# job index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5                                          GCP Data Engineer
# 6                          Senior Data Engineer  - GCP Cloud
# 9                                          Data Scientist II
# ...                                                      ...
# 785673                       Asset Management Data Scientist
# ...

# %%
median_pivot.sort_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[128], line 1
# ----> 1 median_pivot.sort_index()
#
# NameError: name 'median_pivot' is not defined

# %%
df_US = df[df['job_country'] == 'United States']

# %%
df_US
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 5                                       GCP Data Engineer          Anywhere
# 6                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 9                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# ...

# %%
df_US['job_posted_month'] = df_US['job_posted_date'].dt.strftime('%B')
df_US
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[133], line 1
# ----> 1 df_US['job_posted_month'] = df_US['job_posted_date'].dt.strftime('%B')
#       2 df_US
#
# File c:\Users\IBRAHIM\anaconda3\envs\python_data_project\Lib\site-packages\pandas\core\generic.py:6321, in NDFrame.__getattr__(self, name)
#    6314 if (
#    6315     name not in self._internal_names_set
#    6316     and name not in self._metadata
#    6317     and name not in self._accessors
#    6318     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319 ):
#    6320     return self[name]
# -> 6321 return object.__getattribute__(self, name)
#
# File c:\Users\IBRAHIM\anaconda3\envs\python_data_project\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
# ...

# %%
df_US_pivot = df_US.pivot_table(index='job_posted_month', columns='job_title_short', aggfunc='size')

# %%
df_US_pivot.reset_index( inplace=True )
df_US_pivot["month_number"] = pd.to_datetime(df_US_pivot['job_posted_month'], format='%B').dt.month

df_US_pivot["month_number"]
# Out:
# 0      4
# 1      8
# 2     12
# 3      2
# 4      1
# 5      7
# 6      6
# 7      3
# 8      5
# 9     11
# 10    10
# 11     9
# Name: month_number, dtype: int32

# %%
df_US_pivot
# Out:
# job_title_short job_posted_month  Business Analyst  Cloud Engineer  \
# 0                          April               565              40
# 1                         August               903              39
# 2                       December               648              40
# 3                       February               447              24
# 4                        January               527              36
# 5                           July               581              39
# 6                           June               446              32
# 7                          March               438              19
# 8                            May               279              20
# 9                       November               719              36
# 10                       October               932              48
# 11                     September               897              50
#
# job_title_short  Data Analyst  Data Engineer  Data Scientist  \
# ...

# %%
df_US_pivot.plot(kind='line')
top_3 = df_US['job_title_short'].value_counts().head(3)
top_3 = top_3.index.tolist()
df_US_pivot[top_3].plot(kind='line')
plt.ylabel('Number of Job Postings')
plt.title('Job Postings Over Time in the US')
plt.xlabel('')
plt.show()

# %%
df_US_pivot.sort_values('month_number', inplace=True)

df_US_pivot.drop(columns='month_number', inplace=True )

df_US_pivot
# Out:
# job_title_short job_posted_month  Business Analyst  Cloud Engineer  \
# 4                        January               527              36
# 3                       February               447              24
# 7                          March               438              19
# 0                          April               565              40
# 8                            May               279              20
# 6                           June               446              32
# 5                           July               581              39
# 1                         August               903              39
# 11                     September               897              50
# 10                       October               932              48
# 9                       November               719              36
# 2                       December               648              40
#
# job_title_short  Data Analyst  Data Engineer  Data Scientist  \
# ...

# %%
df_US_pivot.set_index('job_posted_month')
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
df_US_software_pivot = pd.read_csv("https://lukeb.co/software_csv", index_col='job_posted_month')
df_US_software_pivot
# Out:
#                   Front-End Developer  Back-End Developer  \
# job_posted_month
# January                         13619                9827
# February                        11456                9116
# March                           11102                8178
# April                           14037                9209
# May                             12126                8864
# June                            12003                8065
# July                            11914                8061
# August                          11571                8191
# September                       14016                8447
# October                         11419                8476
# November                        13771                9034
# December                        14033                9232
#
#                   Full-Stack Developer  UI/UX Designer
# job_posted_month
# January                           5108            4348
# February                          7298            4284
# ...

# %%
df_US_merged = df_US_pivot.merge(df_US_software_pivot, on='job_posted_month')

# %%
top_5 =(
     df_US_merged
     .sum()
     .sort_values(ascending=False)
     .head()
     .index
     .tolist()
)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[105], line 4
#       1 top_5 =(
#       2      df_US_merged
#       3      .sum()
# ----> 4      .sort_values(ascending=False)
#       5      .head()
#       6      .index
#       7      .tolist()
#       8 )
#
# File c:\Users\IBRAHIM\anaconda3\envs\python_data_project\Lib\site-packages\pandas\core\series.py:3888, in Series.sort_values(self, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    3886 else:
#    3887     values_to_sort = self._values
# -> 3888 sorted_index = nargsort(values_to_sort, kind, bool(ascending), na_position)
#    3890 if is_range_indexer(sorted_index, len(sorted_index)):
#    3891     if inplace:
#
# File c:\Users\IBRAHIM\anaconda3\envs\python_data_project\Lib\site-packages\pandas\core\sorting.py:439, in nargsort(items, kind, ascending, na_position, key, mask)
# ...

# %%
df_US_merged[top_5].plot(kind='line')
plt.ylabel('Number of Job Postings')    
plt.title('Top 5 Job Titles Over Time in the US')   
plt.xlabel('')      
plt.ylim(0,20000)
plt.legend(title='Job Title', bbox_to_anchor=(1.05, 1), loc='upper left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 df_US_merged[top_5].plot(kind='line')
#       2 plt.ylabel('Number of Job Postings')
#       3 plt.title('Top 5 Job Titles Over Time in the US')
#
# NameError: name 'top_5' is not defined

# %%
df['job_posted_month'] = df['job_posted_date'].dt.strftime('%b')
months = df['job_posted_month'].unique()
dict_months = {month: df[df['job_posted_month'] == month] for month in months}
dict_months['Jan']
# Out:
#              job_title_short                                  job_title  \
# job index
# 1               Data Analyst                               Data Analyst
# 20            Data Scientist                             Data Scientist
# 39             Data Engineer                              Data Engineer
# 53             Data Engineer                              Data Engineer
# 55            Data Scientist                             Data Scientist
# ...                      ...                                        ...
# 785699     Software Engineer                        Simulation Engineer
# 785700         Data Engineer                       Data Engineer Ssr/Sr
# 785703          Data Analyst    Data Analyst - CRYPTOGRAPHY - Full-time
# 785704      Business Analyst                           Business Analyst
# 785705          Data Analyst  Expert Business Data Analyst - Now Hiring
#
#                                     job_location             job_via  \
# job index
# ...

# %%
df_q1 = pd.concat([dict_months['Jan'], dict_months['Feb'], dict_months['Mar']], ignore_index=True)

# %%
df_q1['job_posted_month'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
df_q1.head().to_clipboard(sep=',')

# %% [markdown]
# ,job_title_short,job_title,job_location,job_via,job_schedule_type,job_work_from_home,search_location,job_posted_date,job_no_degree_mention,job_health_insurance,job_country,salary_rate,salary_year_avg,salary_hour_avg,company_name,job_skills,job_type_skills,job_posted_month
# 0,Data Analyst,Data Analyst,"Guadalajara, Jalisco, Mexico",via BeBee México,Full-time,False,Mexico,2023-01-14 13:18:07,False,False,Mexico,,115000.0,55.28846153846154,Hewlett Packard Enterprise,"['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']","{'analyst_tools': ['power bi', 'tableau'], 'programming': ['r', 'python', 'sql', 'nosql']}",Jan
# 1,Data Scientist,Data Scientist,"Zaventem, Belgium",via BeBee Belgique,Full-time,False,Belgium,2023-01-31 13:53:38,False,False,Belgium,,115000.0,55.28846153846154,Devoteam,"['r', 'python', 'sql', 'pandas', 'numpy', 'scikit-learn', 'matplotlib', 'hadoop', 'spark']","{'libraries': ['pandas', 'numpy', 'scikit-learn', 'matplotlib', 'hadoop', 'spark'], 'programming': ['r', 'python', 'sql']}",Jan
# 2,Data Engineer,Data Engineer,"Fort Worth, TX",via LinkedIn,Full-time,False,"Texas, United States",2023-01-25 13:24:01,False,False,United States,,115000.0,55.28846153846154,Programmers.io,"['sql', 'python']","{'programming': ['sql', 'python']}",Jan
# 3,Data Engineer,Data Engineer,"San Mateo, CA",via LinkedIn,Full-time,False,"California, United States",2023-01-28 13:07:30,False,True,United States,,115000.0,55.28846153846154,Verkada,"['sql', 'python', 'aws', 'looker']","{'analyst_tools': ['looker'], 'cloud': ['aws'], 'programming': ['sql', 'python']}",Jan
# 4,Data Scientist,Data Scientist,"São Paulo, State of São Paulo, Brazil",via BeBee,Full-time,False,Brazil,2023-01-03 23:02:27,False,False,Brazil,,115000.0,55.28846153846154,Mars,"['python', 'sql', 'azure']","{'cloud': ['azure'], 'programming': ['python', 'sql']}",Jan

# %%
df_q1.to_csv('quarter_1.csv')

# %%
pd.read_csv('quarter_1.csv', index_col=0)
# Out:
#           job_title_short                                          job_title  \
# 0            Data Analyst                                       Data Analyst
# 1          Data Scientist                                     Data Scientist
# 2           Data Engineer                                      Data Engineer
# 3           Data Engineer                                      Data Engineer
# 4          Data Scientist                                     Data Scientist
# ...                   ...                                                ...
# 220479  Software Engineer                                    DevOps Engineer
# 220480       Data Analyst                                   CRM Data Analyst
# 220481   Business Analyst                     Commercial Analyst - Start Now
# 220482      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 220483  Software Engineer                                 AWS System Analyst
#
# ...

# %%
df_q1.to_excel('quater_1.xlsx')

# %%
df['salary_year_avg']
# Out:
# job index
# 0         115000.0
# 1         115000.0
# 2         115000.0
# 3         115000.0
# 4         115000.0
#             ...
# 785736    115000.0
# 785737    115000.0
# 785738    115000.0
# 785739    115000.0
# 785740    115000.0
# Name: salary_year_avg, Length: 785741, dtype: float64

# %%
df
# Out:
#                 job_title_short  \
# job index
# 0          Senior Data Engineer
# 1                  Data Analyst
# 2                 Data Engineer
# 3                 Data Engineer
# 4                 Data Engineer
# ...                         ...
# 785736        Software Engineer
# 785737             Data Analyst
# 785738         Business Analyst
# 785739            Data Engineer
# 785740        Software Engineer
#
#                                                    job_title  \
# job index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1                                               Data Analyst
# 2          Data Engineer/Scientist/Analyst, Mid or Senior...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                     Data Engineer- Sr Jobs
# ...                                                      ...
# 785736                                       DevOps Engineer
# ...

# %%
df_filled
# Out:
#                 job_title_short  \
# job index
# 0          Senior Data Engineer
# 1                  Data Analyst
# 2                 Data Engineer
# 3                 Data Engineer
# 4                 Data Engineer
# ...                         ...
# 785736        Software Engineer
# 785737             Data Analyst
# 785738         Business Analyst
# 785739            Data Engineer
# 785740        Software Engineer
#
#                                                    job_title  \
# job index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1                                               Data Analyst
# 2          Data Engineer/Scientist/Analyst, Mid or Senior...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                     Data Engineer- Sr Jobs
# ...                                                      ...
# 785736                                       DevOps Engineer
# ...

# %%
df_original
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
id(df_original) == id(df)
# Out:
# False

# %%
df_original
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df_copy = df_original.copy()

# %%
df_copy
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df_original.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
df = df_copy.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 df = df_copy.copy()
#
# NameError: name 'df_copy' is not defined

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df_salary = df[pd.notna(df['salary_year_avg'])].copy()

# %%
def projected_salary(salary):  
    return salary*1.03

df_salary['salary_year_inflated'] = df_salary['salary_year_avg'].apply(projected_salary)

# %%
df_salary[['salary_year_avg', 'salary_year_inflated']]
# Out:
#         salary_year_avg  salary_year_inflated
# 28             109500.0             112785.00
# 77             140000.0             144200.00
# 92             120000.0             123600.00
# 100            228222.0             235068.66
# 109             89000.0              91670.00
# ...                 ...                   ...
# 785624         139216.0             143392.48
# 785641         150000.0             154500.00
# 785648         221875.0             228531.25
# 785682         157500.0             162225.00
# 785692         157500.0             162225.00
#
# [22003 rows x 2 columns]

# %%
df_salary['salary_year_inflated'] = df_salary['salary_year_avg'].apply(lambda salary: salary*1.03)

df_salary[['salary_year_avg', 'salary_year_inflated']]
# Out:
#         salary_year_avg  salary_year_inflated
# 28             109500.0             112785.00
# 77             140000.0             144200.00
# 92             120000.0             123600.00
# 100            228222.0             235068.66
# 109             89000.0              91670.00
# ...                 ...                   ...
# 785624         139216.0             143392.48
# 785641         150000.0             154500.00
# 785648         221875.0             228531.25
# 785682         157500.0             162225.00
# 785692         157500.0             162225.00
#
# [22003 rows x 2 columns]

# %%
df_salary['salary_year_inflated'] = df_salary['salary_year_avg'] * 1.03

df_salary[['salary_year_avg', 'salary_year_inflated']]
# Out:
#         salary_year_avg  salary_year_inflated
# 28             109500.0             112785.00
# 77             140000.0             144200.00
# 92             120000.0             123600.00
# 100            228222.0             235068.66
# 109             89000.0              91670.00
# ...                 ...                   ...
# 785624         139216.0             143392.48
# 785641         150000.0             154500.00
# 785648         221875.0             228531.25
# 785682         157500.0             162225.00
# 785692         157500.0             162225.00
#
# [22003 rows x 2 columns]

# %%
import ast

ast.literal_eval(df['job_skills'][0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[181], line 3
#       1 import ast
# ----> 3 ast.literal_eval(df['job_skills'][0])
#
# File c:\Users\IBRAHIM\anaconda3\envs\python_data_project\Lib\ast.py:110, in literal_eval(node_or_string)
#     108                 return left - right
#     109     return _convert_signed_num(node)
# --> 110 return _convert(node_or_string)
#
# File c:\Users\IBRAHIM\anaconda3\envs\python_data_project\Lib\ast.py:109, in literal_eval.<locals>._convert(node)
#     107         else:
#     108             return left - right
# --> 109 return _convert_signed_num(node)
#
# File c:\Users\IBRAHIM\anaconda3\envs\python_data_project\Lib\ast.py:83, in literal_eval.<locals>._convert_signed_num(node)
#      81     else:
#      82         return - operand
# ---> 83 return _convert_num(node)
#
# ...

# %%
list(df['job_skills'][0:3])
# Out:
# [None,
#  ['r', 'python', 'sql', 'nosql', 'power bi', 'tableau'],
#  ['python',
#   'sql',
#   'c#',
#   'azure',
#   'airflow',
#   'dax',
#   'docker',
#   'kubernetes',
#   'jenkins']]

# %%
import ast

# %%
df['job_skills'] = df['job_skills'].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) else x
)
df['job_skills']
# Out:
# 0                                                      None
# 1                [r, python, sql, nosql, power bi, tableau]
# 2         [python, sql, c#, azure, airflow, dax, docker,...
# 3         [python, c++, java, matlab, aws, tensorflow, k...
# 4         [bash, python, oracle, aws, ansible, puppet, j...
#                                 ...
# 785736    [bash, python, perl, linux, unix, kubernetes, ...
# 785737                               [sas, sas, sql, excel]
# 785738                                  [powerpoint, excel]
# 785739    [python, go, nosql, sql, mongo, shell, mysql, ...
# 785740                                          [aws, flow]
# Name: job_skills, Length: 785741, dtype: object

# %%
df['job_skills']
# Out:
# 0                                                      None
# 1                [r, python, sql, nosql, power bi, tableau]
# 2         [python, sql, c#, azure, airflow, dax, docker,...
# 3         [python, c++, java, matlab, aws, tensorflow, k...
# 4         [bash, python, oracle, aws, ansible, puppet, j...
#                                 ...
# 785736    [bash, python, perl, linux, unix, kubernetes, ...
# 785737                               [sas, sas, sql, excel]
# 785738                                  [powerpoint, excel]
# 785739    [python, go, nosql, sql, mongo, shell, mysql, ...
# 785740                                          [aws, flow]
# Name: job_skills, Length: 785741, dtype: object

# %%
def projected_salary(row):
    if "senior" in row['job_title_short']:
        return 1.05 * row['salary_year_avg']
    else: 
        return 1.03 * row['salary_year_avg']
    
df_salary['salary_year_inflated'] = df_salary.apply(projected_salary, axis=1)
df_salary[['job_title_short','salary_year_avg','salary_year_inflated']]
# Out:
#        job_title_short  salary_year_avg  salary_year_inflated
# 28      Data Scientist         109500.0             112785.00
# 77       Data Engineer         140000.0             144200.00
# 92       Data Engineer         120000.0             123600.00
# 100     Data Scientist         228222.0             235068.66
# 109       Data Analyst          89000.0              91670.00
# ...                ...              ...                   ...
# 785624   Data Engineer         139216.0             143392.48
# 785641   Data Engineer         150000.0             154500.00
# 785648  Data Scientist         221875.0             228531.25
# 785682  Data Scientist         157500.0             162225.00
# 785692  Data Scientist         157500.0             162225.00
#
# [22003 rows x 3 columns]

# %%
df_skill_list.explode('job_skills')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[193], line 1
# ----> 1 df_skill_list.explode('job_skills')
#
# NameError: name 'df_skill_list' is not defined

# %%
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# %%
type(df['job_skills'])
# Out:
# pandas.core.series.Series

# %%
import ast
df["job_skills"] = df["job_skills"].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) else x
)

# %%
type(df['job_skills'])
# Out:
# pandas.core.series.Series

# %%
s_str = df["job_skills"].astype(str)
type(s_str)
# Out:
# pandas.core.series.Series

# %%
import ast

skills_list = s_str.apply(ast.literal_eval)

# %%
type(skills_list)
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df_copy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[202], line 1
# ----> 1 df_copy
#
# NameError: name 'df_copy' is not defined

# %%
df_1 = df_original.copy()

# %%
df = df_1.copy()

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
type(df['job_skills'])
# Out:
# pandas.core.series.Series

# %%
df_explode = df.explode('job_skills')
df_explode['job_skills'].value_counts()
# Out:
# job_skills
# ['excel']                                                                                                           13238
# ['sql']                                                                                                             11732
# ['python']                                                                                                           8509
# ['python', 'sql']                                                                                                    4753
# ['sql', 'excel']                                                                                                     4399
#                                                                                                                     ...
# ['azure', 'aws', 'oracle', 'windows', 'linux']                                                                          1
# ...

# %%
type(df_explode['job_skills'])
# Out:
# pandas.core.series.Series

# %%
skills_count = df_explode.groupby(['job_title_short', 'job_skills']).size()
type(skills_count)
# Out:
# pandas.core.series.Series

# %%
df_skills_count = skills_count.reset_index(name="skill_count")
df_skills_count
# Out:
#           job_title_short                         job_skills  skill_count
# 0        Business Analyst                ['airflow', 'flow']            1
# 1        Business Analyst                        ['airflow']            2
# 2        Business Analyst                       ['airtable']            1
# 3        Business Analyst   ['alteryx', 'excel', 'power bi']            1
# 4        Business Analyst               ['alteryx', 'excel']            2
# ...                   ...                                ...          ...
# 215215  Software Engineer    ['xamarin', 'ionic', 'windows']            1
# 215216  Software Engineer  ['xamarin', 'node', 'git', 'svn']            1
# 215217  Software Engineer                        ['xamarin']            1
# 215218  Software Engineer                           ['yarn']            2
# 215219  Software Engineer                           ['zoom']            8
#
# [215220 rows x 3 columns]

# %%
df_skills_count = df_skills_count.sort_values('skill_count', ascending=False)
df_skills_count
# Out:
#           job_title_short                                    job_skills  \
# 19078        Data Analyst                                     ['excel']
# 49382        Data Analyst                                       ['sql']
# 136380     Data Scientist                                    ['python']
# 35354        Data Analyst                              ['sql', 'excel']
# 1233     Business Analyst                                     ['excel']
# ...                   ...                                           ...
# 12       Business Analyst   ['alteryx', 'tableau', 'power bi', 'excel']
# 13       Business Analyst  ['alteryx', 'tableau', 'power bi', 'looker']
# 14       Business Analyst                ['alteryx', 'tableau', 'qlik']
# 19       Business Analyst               ['angular', 'excel', 'tableau']
# 215204  Software Engineer               ['word', 'excel', 'smartsheet']
#
#         skill_count
# 19078          8095
# 49382          4997
# 136380         4659
# ...

# %%
job_title = 'Data Analyst'
top_skills = 10
df_skill_final = df_skills_count[df_skills_count['job_title_short'] == job_title].head(top_skills)
df_skill_final.plot(kind='barh', x='job_skills', y='skill_count')
plt.gca().invert_yaxis()
plt.title(f'Top {top_skills} Skills for {job_title}')
plt.xlabel('Job Posting Count')
plt.ylabel('')
plt.legend().set_visible(False)
plt.show()

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
import ast
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# %%
df["job_skills"].iloc[:5]
# Out:
# 0                                                 None
# 1           [r, python, sql, nosql, power bi, tableau]
# 2    [python, sql, c#, azure, airflow, dax, docker,...
# 3    [python, c++, java, matlab, aws, tensorflow, k...
# 4    [bash, python, oracle, aws, ansible, puppet, j...
# Name: job_skills, dtype: object

# %%
df_da = df[df['job_title_short'] == 'Data Analyst'].copy()

# %%
df_da
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                         job_location  \
# 1       Guadalajara, Jalisco, Mexico
# ...

# %%
df_da['job_posted_month_no'] = df_da['job_posted_date'].dt.month

# %%
df_da_explode = df_da.explode('job_skills')
df_da_pivot = df_da_explode.pivot_table(index='job_posted_month_no', columns='job_skills', aggfunc='size', fill_value=0)
df_da_pivot.plot(kind='line')
# Out:
# <Axes: xlabel='job_posted_month_no'>

# %%
df_da_pivot
# Out:
# job_skills           airflow  airtable  alteryx  angular  angular.js  ansible  \
# job_posted_month_no
# 1                        197        17      551       63           2       20
# 2                        169         2      448       49           0       14
# 3                        181         4      442       34           0       23
# 4                        155         4      413       22           0       11
# 5                        128         8      310       30           0       19
# 6                        164        14      393       29           0       14
# 7                        207         4      366       15           0        8
# 8                        197         3      413       21           0       12
# 9                        118         4      317       21           0       14
# 10                       173        11      350       40           0       19
# 11                       169         7      293       24           0       19
# ...

# %%
df_da_pivot.loc['total'] = df_da_pivot.sum()

# %%
df_da_pivot = df_da_pivot[df_da_pivot.loc['total'].sort_values(ascending=False).index]
df_da_pivot = df_da_pivot.drop('total')
df_da_pivot
# Out:
# job_skills             sql  excel  python  tableau  power bi     r   sas  \
# job_posted_month_no
# 1                    11336   8170    6606     5596      4285  3607  3830
# 2                     7947   5772    4751     3936      3307  2576  2634
# 3                     7868   5675    4741     4051      3176  2650  2554
# 4                     7553   5496    4557     3776      3106  2399  2598
# 5                     6617   4773    4070     3245      2695  2093  1940
# 6                     7584   5724    4707     3812      3275  2442  2174
# 7                     7687   5513    4831     3928      3350  2444  2118
# 8                     8823   6482    5576     4533      3859  2975  2560
# 9                     6829   4886    4229     3446      3118  2146  1880
# 10                    7474   5217    4693     3709      3340  2380  2114
# 11                    6652   4776    4233     3284      3012  2159  1738
# 12                    6058   4376    4196     3139      2857  2125  1858
# ...

# %%
df_da_pivot.iloc[:,:5] .plot(kind="line")
plt.title('TOP 5 SKILLS FOR DATA ANALYSTS PER MONTH')
plt.ylabel('count')
plt.xlabel('')
plt.show()

# %%
fig, ax = plt.subplots()
df['job_title_short'].value_counts().plot(kind='bar', ax=ax)
# Out:
# <Axes: xlabel='job_title_short'>

# %%
 df['job_title_short'].value_counts()
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
df['job_schedule_type'].value_counts().head(3)
# Out:
# job_schedule_type
# Full-time     701727
# Contractor     34793
# Internship      8742
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(1, 2)
df['job_title_short'].value_counts().plot(kind='bar', ax=ax[1])
df['job_schedule_type'].value_counts().head(3).plot(kind='bar', ax=ax[0])

fig.tight_layout()

# %%
job_titles = ['Data scientist', 'Data Engineer', 'Data Analyst']

# %%
fig, ax = plt.subplots(3, 1)
for i, job_title in enumerate(job_titles):
   df_plot = df_skills_count[df_skills_count['job_title_short'] == job_title].head(5)
   df_plot.plot(kind='barh', x='job_skills', y='skill_count', ax=ax[i], title=job_title)
   ax[i].invert_yaxis()
   ax[i].set_ylabel('')
   ax[i].legend().set_visible(False)


fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[231], line 4
#       2 for i, job_title in enumerate(job_titles):
#       3    df_plot = df_skills_count[df_skills_count['job_title_short'] == job_title].head(5)
# ----> 4    df_plot.plot(kind='barh', x='job_skills', y='skill_count', ax=ax[i], title=job_title)
#       5    ax[i].invert_yaxis()
#       6    ax[i].set_ylabel('')
#
# File c:\Users\IBRAHIM\anaconda3\envs\python_data_project\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\IBRAHIM\anaconda3\envs\python_data_project\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
# ...

# %%
df
# Out:
#                 job_title_short  \
# job index
# 0          Senior Data Engineer
# 1                  Data Analyst
# 2                 Data Engineer
# 3                 Data Engineer
# 4                 Data Engineer
# ...                         ...
# 785736        Software Engineer
# 785737             Data Analyst
# 785738         Business Analyst
# 785739            Data Engineer
# 785740        Software Engineer
#
#                                                    job_title  \
# job index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1                                               Data Analyst
# 2          Data Engineer/Scientist/Analyst, Mid or Senior...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                     Data Engineer- Sr Jobs
# ...                                                      ...
# 785736                                       DevOps Engineer
# ...

# %%
for job_title in job_titles:
    print(job_title, df_skills_count[df_skills_count['job_title_short'] == job_title].shape[0])
# Out:
# Data scientist 0
# Data Engineer 61683
# Data Analyst 34825

# %%
job_titles
df_skills_count['job_title_short'].unique()
# Out:
# array(['Data Analyst', 'Data Scientist', 'Business Analyst',
#        'Data Engineer', 'Senior Data Analyst', 'Senior Data Scientist',
#        'Software Engineer', 'Machine Learning Engineer',
#        'Senior Data Engineer', 'Cloud Engineer'], dtype=object)

# %%
df[df["job_title_short"] == "Data Scientist"].shape
# Out:
# (172286, 17)

# %%
df[df["job_title_short"] == "Data Scientist"]["job_skills"].isna().mean()
# Out:
# np.float64(0.15369211659682155)

# %%
df_explode[df_explode["job_title_short"] == "Data Scientist"].shape
# Out:
# (172286, 17)

# %%
df_skills_count = (
    df.dropna(subset=["job_skills"])
      .explode("job_skills")
      .groupby(["job_title_short", "job_skills"])
      .size()
      .reset_index(name="skill_count")
)

# %%
import ast
import pandas as pd
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df['job_work_from_home'].value_counts().plot(kind='pie', startangle=90, autopct='%1.1f%%')
plt.title('Work From Home Distribution')
plt.ylabel('')
plt.show()

# %%
df['job_title_short'].value_counts().plot(kind='pie')
plt.title('JOB TITLE SHORT Distribution')
plt.ylabel('')
plt.show()

# %%
df['job_title_short'].value_counts().plot(kind='barh')
plt.title('Job Title Short Distribution')
plt.gca().invert_yaxis()
plt.ylabel('')
plt.show()

# %%
df[['job_work_from_home','job_no_degree_mention','job_health_insurance']]
# Out:
#         job_work_from_home  job_no_degree_mention  job_health_insurance
# 0                    False                  False                 False
# 1                    False                  False                 False
# 2                    False                  False                 False
# 3                    False                   True                 False
# 4                    False                  False                 False
# ...                    ...                    ...                   ...
# 785736               False                  False                 False
# 785737               False                  False                 False
# 785738               False                  False                 False
# 785739               False                  False                 False
# 785740               False                  False                 False
#
# [785741 rows x 3 columns]

# %%
fig, ax = plt.subplots(1, 3)

dict_column={
    'job_work_from_home': 'work from home',
    'job_no_degree_mention': 'job degree required',
    'job_health_insurance': 'health insurance offered'
}
for i, (column, title) in enumerate(dict_column.items()):
    ax[i].pie(df[column].value_counts(), startangle=90, autopct='%1.1f%%', labels=['False', 'True'])
    ax[i].set_title(title)
plt.show()
df_scatter = df[df['job_title_short'] == 'Data Analyst']
df_scatter_exploded = df_scatter.explode('job_skills')
skill_stats = df_scatter_exploded.groupby('job_skills').agg(
    skill_count=('job_skills', 'count'),
    median_salary=('salary_year_avg', 'median') 
)

skill_stats = skill_stats.sort_values(by='skill_count', ascending=False).head(10)
skill_stats.plot(kind='scatter', x='skill_count', y='median_salary')
plt.title('Top 10 Skills for Data Analysts: Count vs Median Salary')
plt.xlabel('count of job postings')
plt.ylabel('median yearly salary(USD)')
plt.tight_layout()

for w, txt in enumerate(skill_stats.index):
    plt.text(skill_stats['skill_count'].iloc[w], skill_stats['median_salary'].iloc[w], txt, fontsize=10)
    # plt.text(skill_stats.iloc[w]['skill_count'], skill_stats.iloc[w]['median_salary'], txt, fontsize=10)
    # plt.annotate(txt, (skill_stats.iloc[w]['skill_count'], skill_stats.iloc[w]['median_salary']), fontsize=10)

plt.show()

# %%
# df_aa = df[df['job_title_short'] == 'Data Analyst'].copy()

# %%
df_da_pivot
# Out:
# job_skills             sql  excel  python  tableau  power bi     r   sas  \
# job_posted_month_no
# 1                    11336   8170    6606     5596      4285  3607  3830
# 2                     7947   5772    4751     3936      3307  2576  2634
# 3                     7868   5675    4741     4051      3176  2650  2554
# 4                     7553   5496    4557     3776      3106  2399  2598
# 5                     6617   4773    4070     3245      2695  2093  1940
# 6                     7584   5724    4707     3812      3275  2442  2174
# 7                     7687   5513    4831     3928      3350  2444  2118
# 8                     8823   6482    5576     4533      3859  2975  2560
# 9                     6829   4886    4229     3446      3118  2146  1880
# 10                    7474   5217    4693     3709      3340  2380  2114
# 11                    6652   4776    4233     3284      3012  2159  1738
# 12                    6058   4376    4196     3139      2857  2125  1858
# ...

# %%
df_da_pivot.iloc[:,:5] .plot(
    kind="line",
    linewidth=4,
    linestyle=':',
    colormap='viridis',
    marker='o',
    markersize=8,
    figsize=(10,6)
    )
plt.title('TOP 5 SKILLS FOR DATA ANALYSTS PER MONTH')
plt.ylabel('count')
plt.xlabel('')
plt.show()

# %%
df_scatter = df[df['job_title_short'] == 'Data Analyst']
df_scatter_exploded = df_scatter.explode('job_skills')
skill_stats = df_scatter_exploded.groupby('job_skills').agg(
    skill_count=('job_skills', 'count'),
    median_salary=('salary_year_avg', 'median') 
)

skill_stats = skill_stats.sort_values(by='skill_count', ascending=False).head(20)
skill_stats.plot(kind='scatter', x='skill_count', y='median_salary')
plt.title('Top 20 Skills for Data Analysts: Count vs Median Salary')
plt.xlabel('count of job postings')
plt.ylabel('median yearly salary(USD)')
plt.tight_layout()

for w, txt in enumerate(skill_stats.index):
    plt.text(skill_stats['skill_count'].iloc[w], skill_stats['median_salary'].iloc[w], txt, fontsize=10)
    # plt.text(skill_stats.iloc[w]['skill_count'], skill_stats.iloc[w]['median_salary'], txt, fontsize=10)
    # plt.annotate(txt, (skill_stats.iloc[w]['skill_count'], skill_stats.iloc[w]['median_salary']), fontsize=10)

plt.show()

# %%
from adjustText import adjust_text

df_scatter = df[df['job_title_short'] == 'Data Analyst']
df_scatter_exploded = df_scatter.explode('job_skills')
skill_stats = df_scatter_exploded.groupby('job_skills').agg(
    skill_count=('job_skills', 'count'),
    median_salary=('salary_year_avg', 'median') 
)

skill_stats = skill_stats.sort_values(by='skill_count', ascending=False).head(20)
skill_stats.plot(kind='scatter', x='skill_count', y='median_salary')
plt.title('Top 20 Skills for Data Analysts: Count vs Median Salary')
plt.xlabel('count of job postings')
plt.ylabel('median yearly salary(USD)')
plt.tight_layout()

texts =[]
for w, txt in enumerate(skill_stats.index):
    texts.append(plt.text(skill_stats['skill_count'].iloc[w], skill_stats['median_salary'].iloc[w], txt, fontsize=10))
adjust_text(texts, arrowprops=dict(arrowstyle='->', color='gray', lw=0.5))
ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${int(x/1000)}K'))
# ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1000:,.0f}K'))
    # plt.text(skill_stats.iloc[w]['skill_count'], skill_stats.iloc[w]['median_salary'], txt, fontsize=10)
    # plt.annotate(txt, (skill_stats.iloc[w]['skill_count'], skill_stats.iloc[w]['median_salary']), fontsize=10)

plt.show()

# %%
df_da_us = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')].copy()

# %%
df_da_us['salary_year_avg']
# Out:
# 36       NaN
# 68       NaN
# 73       NaN
# 79       NaN
# 93       NaN
#           ..
# 785603   NaN
# 785626   NaN
# 785685   NaN
# 785703   NaN
# 785705   NaN
# Name: salary_year_avg, Length: 67816, dtype: float64

# %%
df_da_us['salary_year_avg'].plot(kind='hist', bins=35, edgecolor='black')
plt.xlim(0, 250000)

ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${int(x/1000)}K'))

plt.title('Distribution of United States Data Analyst Salaries')
plt.xlabel('Salary (USD)')
plt.ylabel('number of JOBS')
plt.tight_layout()
plt.show()

# %%
df_da_us = df.loc[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')]
df_da_us
# Out:
#        job_title_short                                     job_title  \
# 36        Data Analyst                                  Data Analyst
# 68        Data Analyst                     Sr. Research Data Analyst
# 73        Data Analyst   Entry level / Systems Data Analyst (Remote)
# 79        Data Analyst                    Data Analyst/Report Writer
# 93        Data Analyst  IT Finance / TBM Data Analyst - Remote | WFH
# ...                ...                                           ...
# 785603    Data Analyst                           Junior Data Analyst
# 785626    Data Analyst                    Data Acquisition Associate
# 785685    Data Analyst                                  Data Analyst
# 785703    Data Analyst       Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst     Expert Business Data Analyst - Now Hiring
#
#             job_location               job_via job_schedule_type  \
# 36        Des Moines, IA       via Trabajo.org         Full-time
# ...

# %%
df_da_us = df_da_us.dropna(subset=['salary_year_avg'])
df_da_us['salary_year_avg'].sample(10)
# Out:
# 243958    135000.0
# 542392    100774.5
# 80783      65000.0
# 403710     66661.5
# 598202     97500.0
# 126221    125930.0
# 315568     89000.0
# 218920     65000.0
# 691749     83500.0
# 539996     82500.0
# Name: salary_year_avg, dtype: float64

# %%
df_da_us['salary_year_avg'].describe()
# Out:
# count      4350.000000
# mean      94553.964924
# std       33248.650655
# min       25000.000000
# 25%       71262.500000
# 50%       90000.000000
# 75%      112500.000000
# max      375000.000000
# Name: salary_year_avg, dtype: float64

# %%
# df_da_us['salary_year_avg'].plot(kind="box")
# plt.title('Boxplot of United States Data Analyst Salaries')
# plt.ylabel('Salary (USD)')
# plt.show()
job_titles = ['Data Analyst','Data Engineer','Data Scientist']
df_us = df.loc[(df['job_title_short'].isin(job_titles)) & (df['job_country'] == 'United States')]
df_us = df_us.dropna(subset=['salary_year_avg'])
job_list = [df_us[df_us['job_title_short'] == job_title]['salary_year_avg'] for job_title in job_titles]

plt.boxplot(job_list, labels=job_titles, vert=False)
plt.title('Boxplot of United States Data Job Salaries')
plt.xlabel('Salary (USD)')
plt.xlim(0, 600000)
ax= plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${int(x/1000)}K'))
plt.tight_layout()
plt.show()
# Out:
# C:\Users\IBRAHIM\AppData\Local\Temp\ipykernel_2212\607406918.py:10: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(job_list, labels=job_titles, vert=False)

# %%
job_list[0]
# Out:
# 109        89000.0
# 180        90250.0
# 410       133285.0
# 988        62623.0
# 1413       71300.0
#             ...
# 782637     70000.0
# 782798    111175.0
# 783588    125000.0
# 783866    115000.0
# 784882     87500.0
# Name: salary_year_avg, Length: 4350, dtype: float64

# %%
df_us['job_title_short'].value_counts()
# Out:
# job_title_short
# Data Analyst      67816
# Data Scientist    58830
# Data Engineer     35080
# Name: count, dtype: int64

# %%
df_us['salary_year_avg']
# Out:
# 92        120000.0
# 100       228222.0
# 109        89000.0
# 116       114000.0
# 146       129500.0
#             ...
# 785563    136400.0
# 785624    139216.0
# 785641    150000.0
# 785648    221875.0
# 785692    157500.0
# Name: salary_year_avg, Length: 11818, dtype: float64

# %%
df_da_us
# Out:
#        job_title_short                                    job_title  \
# 109       Data Analyst        Senior Supply Chain Analytics Analyst
# 180       Data Analyst                             Data Analyst III
# 410       Data Analyst  IT Business Lead Data Analyst - VP - Hybrid
# 988       Data Analyst                        DATA ANALYST (ONSITE)
# 1413      Data Analyst                          Junior BI Developer
# ...                ...                                          ...
# 782637    Data Analyst                     Data Integration Analyst
# 782798    Data Analyst                       Reference Data Analyst
# 783588    Data Analyst                       Data Analytics Manager
# 783866    Data Analyst              Lead Credit Bureau Data Analyst
# 784882    Data Analyst         Merchandising Analyst (Data Analyst)
#
#               job_location                job_via job_schedule_type  \
# 109               Anywhere             via Get.It         Full-time
# ...

# %%
df_da_us = df_da_us.explode('job_skills')
df_da_us['job_skills']
# Out:
# 109        python
# 109             r
# 109       alteryx
# 109       tableau
# 180         excel
#            ...
# 784882        sql
# 784882        vba
# 784882    tableau
# 784882      excel
# 784882    alteryx
# Name: job_skills, Length: 17440, dtype: object

# %%
df_da_us_group = df_da_us.groupby('job_skills')['salary_year_avg'].agg(
    count='count',
    median='median'
)
df_da_us_group
# Out:
#             count     median
# job_skills
# airflow        44  116250.00
# airtable        5   90000.00
# alteryx       106  106281.25
# angular         8  107500.00
# ansible         1  159640.00
# ...           ...        ...
# wire            4   74250.00
# word          461   81194.75
# workfront       3   75000.00
# wrike           1   75000.00
# zoom           15   80740.00
#
# [170 rows x 2 columns]

# %%
df_da_top_pay = df_da_us_group.sort_values('median', ascending=False).head(10)
df_da_top_pay
# Out:
#               count    median
# job_skills
# dplyr             2  196250.0
# bitbucket         3  189000.0
# gitlab            3  186000.0
# solidity          1  179000.0
# hugging face      1  175000.0
# couchbase         1  160515.0
# ansible           1  159640.0
# mxnet             2  149000.0
# cassandra         6  148250.0
# vmware            1  147500.0

# %%
df_da_skills = df_da_us_group.sort_values('count', ascending=False).head(10).sort_values('median', ascending=False)
df_da_skills
# Out:
#             count    median
# job_skills
# python       1431  97500.00
# tableau      1364  92875.00
# r             893  92500.00
# sql server    286  92500.00
# sql          2508  91000.00
# sas           926  90000.00
# power bi      838  90000.00
# powerpoint    462  85000.00
# excel        1808  84392.00
# word          461  81194.75

# %%
fig, ax = plt.subplots(2, 1)
df_da_top_pay.plot(kind='barh', y='median', ax=ax[0], legend=False)
ax[0].invert_yaxis()
ax[0].set_title('Top 10 Skills for Data Analysts by Median Salary')
ax[0].set_xlabel('')
ax[0].set_ylabel('')
ax[0].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${int(x/1000)}K'))
df_da_skills.plot(kind='barh', ax=ax[1], legend=False)
ax[1].invert_yaxis()
ax[1].set_title('Top 10 most in-demandSkills for Data Analysts')
ax[1].set_xlabel('Medain Salary(USD)')
ax[1].set_ylabel('')
ax[1].set_xlim(ax[0].get_xlim())
ax[1].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${int(x/1000)}K'))
# plt.tight_layout()
fig.tight_layout()
# df_da_top_pay['median'].plot(kind='barh', ax=x[0], title='Top 10 Skills for Data Analysts by Median Salary')
# df_da_skills['count'].plot(kind='barh', ax=x[1], title='Top 10 Skills for Data Analysts by Count of Job Postings')

# %%
import seaborn as sns

fig, ax = plt.subplots(2, 1)

sns.set_theme(style="ticks")
sns.barplot(data=df_da_top_pay, y=df_da_top_pay.index, x='median', ax=ax[0], hue='median', palette='dark:b_r')
ax[0].legend().remove()
# df_da_top_pay.plot(kind='barh', y='median', ax=ax[0], legend=False)
# ax[0].invert_yaxis()
ax[0].set_title('Top 10 Skills for Data Analysts by Median Salary')
ax[0].set_xlabel('')
ax[0].set_ylabel('')
ax[0].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${int(x/1000)}K'))

sns.barplot(data=df_da_skills, y=df_da_skills.index, x='median', ax=ax[1], hue='median', palette='dark:b_r')
ax[1].legend().remove()
# df_da_skills.plot(kind='barh', ax=ax[1], legend=False)
# ax[1].invert_yaxis()
ax[1].set_title('Top 10 most in-demandSkills for Data Analysts')
ax[1].set_xlabel('Medain Salary(USD)')
ax[1].set_ylabel('')
ax[1].set_xlim(ax[0].get_xlim())
ax[1].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${int(x/1000)}K'))
# plt.tight_layout()
fig.tight_layout()
# df_da_top_pay['median'].plot(kind='barh', ax=x[0], title='Top 10 Skills for Data Analysts by Median Salary')
# df_da_skills['count'].plot(kind='barh', ax=x[1], title='Top 10 Skills for Data Analysts by Count of Job Postings')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 import seaborn as sns
# ----> 3 fig, ax = plt.subplots(2, 1)
#       5 sns.set_theme(style="ticks")
#       6 sns.barplot(data=df_da_top_pay, y=df_da_top_pay.index, x='median', ax=ax[0], hue='median', palette='dark:b_r')
#
# NameError: name 'plt' is not defined

# %%
# df_da_us['salary_year_avg'].plot(kind='hist', bins=35, edgecolor='black')
# plt.xlim(0, 250000)
sns.set_theme(style="ticks")
sns.displot(data=df_da_us, x='salary_year_avg', kind='kde',fill=True )

ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${int(x/1000)}K'))

plt.title('Distribution of United States Data Analyst Salaries')
plt.xlabel('Salary (USD)')
plt.ylabel('number of JOBS')
plt.tight_layout()
plt.show()

# %%
# df_da_us['salary_year_avg'].plot(kind="box")
# plt.title('Boxplot of United States Data Analyst Salaries')
# plt.ylabel('Salary (USD)')
# plt.show()
job_titles = ['Data Analyst','Data Engineer','Data Scientist']
df_us = df.loc[(df['job_title_short'].isin(job_titles)) & (df['job_country'] == 'United States')]
df_us = df_us.dropna(subset=['salary_year_avg'])
job_list = [df_us[df_us['job_title_short'] == job_title]['salary_year_avg'] for job_title in job_titles]


plt.boxplot(job_list, labels=job_titles, vert=False)
plt.title('Boxplot of United States Data Job Salaries')
plt.xlabel('Salary (USD)')
plt.xlim(0, 600000)
ax= plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${int(x/1000)}K'))
plt.tight_layout()
plt.show()
# Out:
# C:\Users\IBRAHIM\AppData\Local\Temp\ipykernel_2212\3717008068.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(job_list, labels=job_titles, vert=False)

# %%
# df_da_us['salary_year_avg'].plot(kind="box")
# plt.title('Boxplot of United States Data Analyst Salaries')
# plt.ylabel('Salary (USD)')
# plt.show()
job_titles = ['Data Analyst','Data Engineer','Data Scientist']
df_us = df.loc[(df['job_title_short'].isin(job_titles)) & (df['job_country'] == 'United States')]
df_us = df_us.dropna(subset=['salary_year_avg'])
job_list = [df_us[df_us['job_title_short'] == job_title]['salary_year_avg'] for job_title in job_titles]

# plt.boxplot(job_list, labels=job_titles, vert=False)

sns.boxplot(data=df_us, x='salary_year_avg', y='job_title_short', orient='h')


plt.title('Boxplot of United States Data Job Salaries')
plt.ylabel('')
plt.xlabel('Salary (USD)')
plt.xlim(0, 600000)
ax= plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${int(x/1000)}K'))
plt.tight_layout()
plt.show()
